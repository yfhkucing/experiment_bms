# %% [markdown]
# <a href="https://colab.research.google.com/github/yfhkucing/experiment_bms/blob/master/visualisasi_excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
# membaca data dari excel, masukkan nama files dan extensinya dan nama fari sheet excel
df = pd.read_excel("DataTN7.xlsx", sheet_name="Fan 13")

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      koor_x  koor_y  koor_z        Vx        Vy        Vz      Temp      Laju
# 0       1.0    65.0    18.0  0.000437 -0.024000 -0.017120  22.74250  0.024004
# 1       1.0    96.0    18.0 -0.001790 -0.014710 -0.011650  22.29534  0.014819
# 2       1.0    80.0    18.0 -0.000410 -0.017820 -0.017420  22.48410  0.017825
# 3       1.0     6.0    18.0  0.002482 -0.028540 -0.005540  23.55994  0.028648
# 4       1.0    47.0    18.0  0.000497 -0.029480 -0.017030  23.04712  0.029484
# ..      ...     ...     ...       ...       ...       ...       ...       ...
# 457    96.0   119.0    18.0  0.038469  0.005831  0.021827  25.61872  0.038908
# 458    96.0   108.0    18.0  0.012063  0.001677  0.015323  25.55921  0.012179
# 459    96.0    80.0    18.0  0.008393 -0.004450  0.001548  25.40483  0.009500
# 460    96.0   174.0    18.0  0.028503 -0.029570  0.000706  24.30705  0.041071
# 461    96.0    96.0    18.0  0.008354 -0.001620  0.005228  25.46672  0.008510
#
# [462 rows x 8 columns]

# %%
#drop koor_z, Vz, Temoerature, Laju

df.pop("koor_z")
df.pop("Vz")
df.pop("Temp")
df.pop("Laju")
df
# Out:
#      koor_x  koor_y        Vx        Vy
# 0       1.0    65.0  0.000437 -0.024000
# 1       1.0    96.0 -0.001790 -0.014710
# 2       1.0    80.0 -0.000410 -0.017820
# 3       1.0     6.0  0.002482 -0.028540
# 4       1.0    47.0  0.000497 -0.029480
# ..      ...     ...       ...       ...
# 457    96.0   119.0  0.038469  0.005831
# 458    96.0   108.0  0.012063  0.001677
# 459    96.0    80.0  0.008393 -0.004450
# 460    96.0   174.0  0.028503 -0.029570
# 461    96.0    96.0  0.008354 -0.001620
#
# [462 rows x 4 columns]

# %%
df.describe()
# Out:
#            koor_x      koor_y          Vx          Vy
# count  462.000000  462.000000  462.000000  462.000000
# mean    53.909091  101.857143    0.005030   -0.001457
# std     33.968410   62.003579    0.035639    0.059836
# min      1.000000    6.000000   -0.279660   -0.702210
# 25%     20.000000   47.000000    0.000000   -0.004575
# 50%     57.000000  102.000000    0.003990    0.001242
# 75%     86.000000  153.000000    0.009816    0.010765
# max    106.000000  203.000000    0.198516    0.072435

# %%
import plotly.graph_objects as go
from plotly.figure_factory import create_quiver

# koordinat x = x
# koor y = y
# magnitude sumbu x = Vx
# magnitude sumbu y = Vy
# tipe data masing2 array, bisa dubah di excelnya
# a = [ 1, 2, 3]
# 3 parameter, file yg mau divisualisasi, skala panah, skala kepala panah

def tampilan_vektor(Y,scale,arrow):
  x = - Y['koor_x']
  y = Y['koor_y']
  u =  - Y['Vx']
  v = Y['Vy']

  fig = create_quiver(x,y,u,v, scale=scale, arrow_scale=arrow)
  
  fig.show()

# %%
# masukkan parameter di dalam kurung fungsi sesuai urutan

tampilan_vektor(df,50,0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
