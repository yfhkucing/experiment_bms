# %% [markdown]
# <a href="https://colab.research.google.com/github/yfhkucing/experiment_bms/blob/master/experiment_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/data bms.xlsx',sheet_name='data_asli')
df.pop('avg_temp')
# Out:
# 0      30.02
# 1      27.44
# 2      23.44
# 3      24.63
# 4      23.94
#        ...
# 187    24.30
# 188    24.21
# 189    24.92
# 190    22.16
# 191    25.80
# Name: avg_temp, Length: 192, dtype: float64

# %%
df
# Out:
#      Jendela  AC  Arah Sudut Kecepatan Angin derajat  Nilai Kecepatan Angin  \
# 0          0   0                                 171                    0.5
# 1          0   0                                 153                    0.4
# 2          0   0                                  47                    4.8
# 3          0   0                                  62                    4.1
# 4          0   0                                 341                    3.8
# ..       ...  ..                                 ...                    ...
# 187        1   1                                 163                    0.9
# 188        1   1                                 210                    0.1
# 189        1   1                                 247                    0.3
# 190        1   1                                 265                    1.0
# 191        1   1                                  64                    0.2
#
#      Dry Bulb Temperature  Fan
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
feature=['Jendela',
         'AC',
         'Arah Sudut Kecepatan Angin derajat',
         'Nilai Kecepatan Angin',
         'Dry Bulb Temperature',
         'Fan']
fig, ax =plt.subplots(1,6)
fig.set_size_inches(15, 10)
v=0
for i in feature:
    sns.boxplot(y=df[i], ax=ax[v])
    v=v+1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#correlation
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")
